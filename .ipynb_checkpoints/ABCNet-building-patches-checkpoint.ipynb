# %% [markdown]
# # Building Segmentation

# %%
import glob
import matplotlib.pyplot as plt
import numpy as np
import tifffile as tiff
import cv2
import os

import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.metrics import MeanIoU, Accuracy

# %%
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_virtual_device_configuration(gpus[0], [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4096)])
    except RuntimeError as e:
        print(e)

# %%
gpus
# Out:
# []

# %%
# import numpy as np

# def extract_padded_patches(image, patch_size=(512, 512)):
#     height, width = image.shape[:2]
#     patch_height, patch_width = patch_size

#     num_patches_y = (height + patch_height - 1) // patch_height
#     num_patches_x = (width + patch_width - 1) // patch_width

#     # Calculate padding
#     pad_y = num_patches_y * patch_height - height
#     pad_x = num_patches_x * patch_width - width

#     # Pad the image
#     padded_image = np.pad(image, ((0, pad_y), (0, pad_x), (0, 0)), mode='constant')
#     #print(padded_image.shape)
    
#     # Extract patches
#     patches = []

#     for y in range(0, num_patches_y * patch_height, patch_height):
#         for x in range(0, num_patches_x * patch_width, patch_width):
#             patch = padded_image[y:y+patch_height, x:x+patch_width]
#             #plt.imshow(patch/255)
#             patches.append(patch)

#     return np.array(patches)

# #load the .npz file
# def load_images(path,name, labels):
#     npzfile=np.load(path+"{}.npz".format(name))
#     images=npzfile['arr_0']
#     #patches_image=np.zeros()
#     images =[extract_padded_patches(image, (512, 512)) for image in images]
#     images = [patch for patches in images for patch in patches]


#     npzfile=np.load(path+"{}.npz".format(labels))
#     labels=npzfile['arr_0']
#     #labels=[color.rgb2gray(resize(x,(512,512),mode='constant', preserve_range=True)) for x in labels]
    
#     labels =[extract_padded_patches(image, (512, 512)) for image in labels]
#     labels = [patch for patches in labels for patch in patches]
#     labels = np.array(labels)
#     labels=[cv2.threshold(color.rgb2gray(gt), 128, 1, cv2.THRESH_BINARY)[1] for gt in labels]
    
#     return np.array(images),  np.reshape(np.array(labels), (-1, 512, 512, 1))

# %%
# import matplotlib.pyplot as plt

# # Assume 'patches' is a list of images obtained from extract_padded_patches function

# # Create a figure with subplots
# fig, axs = plt.subplots(1, len(patches), figsize=(15, 5))

# # Iterate through patches and display them
# for i, patch in enumerate(patches):
#     axs[i].imshow(patch/255)
#     axs[i].axis('off')
#     axs[i].set_title(f'Patch {i + 1}')

# # Show the plot
# plt.show()

# %%
#load the .npz file
def load_images(path, name, labels):
    npzfile=np.load(path+"{}.npz".format(name))
    images=npzfile['arr_0']


    npzfile=np.load(path+"{}.npz".format(labels))
    labels=npzfile['arr_0']

    return images, labels

# %%
path='E:\\Pavithra\\building\\'

x_train,y_train = load_images(path,'x_train_patches','y_train_patches')


x_val,y_val = load_images(path,'x_val_patches','y_val_patches')


x_test,y_test = load_images(path,'x_test_patches','y_test_patches')


x_train.sort()
y_train.sort()

x_val.sort()
y_val.sort()

x_test.sort()
y_test.sort()

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# (1233, 512, 512, 3) (1233, 512, 512, 1) (90, 512, 512, 3) (90, 512, 512, 1)

# %%
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape)
# Out:
# (1233, 512, 512, 3) (1233, 512, 512, 1) (36, 512, 512, 3) (36, 512, 512, 1) (90, 512, 512, 3) (90, 512, 512, 1)

# %%
from tensorflow.keras.utils import Sequence
import numpy as np 
class DataGenerator(Sequence):
    def __init__(self, x_set, y_set, batch_size):
        self.x, self.y = x_set, y_set
        self.batch_size = batch_size

    def __len__(self):
        return int(np.ceil(len(self.x) / float(self.batch_size)))

    def __getitem__(self, idx):
        batch_x = self.x[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.y[idx * self.batch_size:(idx + 1) * self.batch_size]
        return batch_x, batch_y

train_gen = DataGenerator(x_train, y_train, 1)
val_gen = DataGenerator(x_val, y_val, 1)

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
fig.figsize = (30,30)

ax = fig.add_subplot(1,2,1)
ax.imshow(np.reshape(y_train[1]/255,(512,512)),cmap="gray")
plt.axis('off')
plt.title("Ground-truth")

ax = fig.add_subplot(1,2,2)
ax.imshow(x_train[1]/255)
plt.axis('off')
plt.title("Actual image")
# Out:
# Text(0.5, 1.0, 'Actual image')

# %% [markdown]
# # Loss

# %%
def precision(y_true, y_pred):
    smooth = 1
    y_pred_pos = K.clip(y_pred, 0, 1)
    y_pred_neg = 1 - y_pred_pos
    y_pos = K.clip(y_true, 0, 1)
    y_neg = 1 - y_pos
    tp = K.sum(y_pos * y_pred_pos)
    fp = K.sum(y_neg * y_pred_pos)
    fn = K.sum(y_pos * y_pred_neg)
    precision = (tp + smooth) / (tp + fp + smooth)
    return precision


def recall(y_true, y_pred):
    smooth = 1
    y_pred_pos = K.clip(y_pred, 0, 1)
    y_pred_neg = 1 - y_pred_pos
    y_pos = K.clip(y_true, 0, 1)
    y_neg = 1 - y_pos
    tp = K.sum(y_pos * y_pred_pos)
    fp = K.sum(y_neg * y_pred_pos)
    fn = K.sum(y_pos * y_pred_neg)
    recall = (tp + smooth) / (tp + fn + smooth)
    return recall

# %%
from keras import backend as K
from keras.losses import binary_crossentropy
import tensorflow as tf

def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def iou_coef(y_true, y_pred, smooth=1):
    intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
    union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
    iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
    return iou

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. - score

def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(tf.cast(y_true, tf.float32), y_pred) + 0.5 * dice_loss(tf.cast(y_true, tf.float32), y_pred)

# %%
import tensorflow as tf

def create_callbacks():
    # Reduce learning rate on plateau
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        mode='min',
        factor=0.5,
        patience=2,
        verbose=1,
        cooldown=1,
        min_delta=0.0001
    )

    # Early stopping
    early_stop = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        min_delta=0.0001,
        patience=3,
        verbose=1,
        mode='min',
        restore_best_weights=True
    )

    # Model checkpoint
    # Define the path using os.path.join for cross-platform compatibility
    check_path = os.path.join('.', 'morphUnet_building.h5')
    checkpoint = tf.keras.callbacks.ModelCheckpoint(
        check_path,
        monitor='val_loss',
        verbose=1,
        save_best_only=True,
        save_weights_only=True,
        mode='min'
    )

    return [reduce_lr, early_stop, checkpoint]

# Usage example:

# %%
import matplotlib.pyplot as plt

def plot_history(history):
    # Accuracy plot
    plt.plot(history['accuracy'], label='train_acc')
    plt.plot(history['val_accuracy'], '--', label='val_acc')
    plt.legend()
    plt.xlabel("No. of epochs")
    plt.ylabel("Accuracy")
    plt.title("Training and Validation Accuracy")
    plt.show()

    # Loss plot
    plt.plot(history['loss'], label='train_loss')
    plt.plot(history['val_loss'], '--', label='val_loss')
    plt.legend()
    plt.xlabel("No. of epochs")
    plt.ylabel("Loss")
    plt.title("Training and Validation Loss")
    plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report, cohen_kappa_score, precision_score, recall_score

def get_dice(y_true, y_pred):
    intersection = np.sum(y_true * y_pred, axis=(0, 1, 2))
    union = np.sum(y_true**2, axis=(0, 1, 2)) + np.sum(y_pred**2, axis=(0, 1, 2))
    dc = 2 * intersection / union
    return dc


def evaluate_segmentation(y_test, y_pred):
    # Mean Intersection over Union
    mean_iou = MeanIoU(2)
    mean_iou.update_state(y_test, y_pred)
    class_iou = mean_iou.result().numpy()
    mean_iou.reset_states()
    
    # Accuracy
    acc = Accuracy()
    acc.update_state(y_test, y_pred)
    accuracy = acc.result().numpy()
    acc.reset_states()
    
    # Precision
    precision = precision_score(y_test.ravel(), y_pred.ravel(), average='binary')
    
    # Recall
    recall = recall_score(y_test.ravel(), y_pred.ravel(), average='binary')
    
    # Confusion Matrix
    cm = confusion_matrix(y_test.ravel(), y_pred.ravel())
    
    # Classification Report
    cr = classification_report(y_test.ravel(), y_pred.ravel())
    
    # Cohen's Kappa Score
    kappa = cohen_kappa_score(y_test.ravel(), y_pred.ravel())
    
    # Dice Coefficient
    dice_coeff = get_dice(y_test, y_pred)
    mean_dice_coeff = np.mean(dice_coeff)
    
    return {
        "mean_iou": mean_iou,
        "class_iou": class_iou,
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "confusion_matrix": cm,
        "classification_report": cr,
        "cohen_kappa_score": kappa,
        "dice_coefficient": dice_coeff,
        "mean_dice_coefficient": mean_dice_coeff
    }

# %%
import matplotlib.pyplot as plt

def visualize_predictions(x_test, y_test, y_pred, num_samples=10):
    fig = plt.figure(figsize=(20, 15))

    for i in range(num_samples):
        # Plot input image
        ax = fig.add_subplot(num_samples, 3, 3*i+1)
        ax.imshow(np.reshape(x_test[i]/255, (512, 512,3)))
        plt.axis('off')
        plt.title("Input image")

        # Plot ground truth
        ax = fig.add_subplot(num_samples, 3, 3*i+2)
        ax.imshow(np.reshape(y_test[i], (512, 512)), cmap="gray")
        plt.axis('off')
        plt.title("Ground-truth")

        # Plot predicted image
        ax = fig.add_subplot(num_samples, 3, 3*i+3)
        ax.imshow(np.reshape(y_pred[i], (512, 512)), cmap="gray")
        plt.axis('off')
        plt.title("Predicted image")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # **Dual Path Morph Unet**

# %%
import tensorflow as tf
from tensorflow.keras.layers import Layer
from keras import initializers, constraints
import tensorflow.keras.utils as conv_utils
from keras import backend as K


class Erosion2D(Layer):
    def __init__(
        self,
        num_filters,
        kernel_size,
        strides=(1, 1),
        padding="valid",
        kernel_initializer="glorot_uniform",
        kernel_constraint=None,
        **kwargs
    ):
        super(Erosion2D, self).__init__(**kwargs)
        self.num_filters = num_filters
        self.kernel_size = kernel_size
        self.strides = strides
        self.padding = padding

        self.kernel_initializer = initializers.get(kernel_initializer)
        self.kernel_constraint = constraints.get(kernel_constraint)
        self.channel_axis = -1

    def build(self, input_shape):
        if input_shape[self.channel_axis] is None:
            raise ValueError(
                "The channel dimension of the inputs "
                "should be defined. Found `None`."
            )

        input_dim = input_shape[self.channel_axis]
        kernel_shape = self.kernel_size + (input_dim, self.num_filters)

        self.kernel = self.add_weight(
            shape=kernel_shape,
            initializer=self.kernel_initializer,
            name="kernel",
            constraint=self.kernel_constraint,
        )

        # Be sure to call this at the end
        super(Erosion2D, self).build(input_shape)

    def call(self, x):
        outputs = K.placeholder()
        for i in range(self.num_filters):
            # erosion2d returns image of same size as x
            # so taking min over channel_axis
            out = K.min(
                self.__erosion2d(x, self.kernel[..., i], self.strides, self.padding),
                axis=self.channel_axis,
                keepdims=True,
            )

            if i == 0:
                outputs = out
            else:
                outputs = K.concatenate([outputs, out])

        return outputs

    def compute_output_shape(self, input_shape):
        # if self.data_format == 'channels_last':
        space = input_shape[1:-1]
        new_space = []
        for i in range(len(space)):
            new_dim = conv_utils.conv_output_length(
                space[i],
                self.kernel_size[i],
                padding=self.padding,
                stride=self.strides[i],
                dilation=1,
            )  # self.erosion_rate[i])
            new_space.append(new_dim)

        return (input_shape[0],) + tuple(new_space) + (self.num_filters,)

    def __erosion2d(self, x, st_element, strides, padding, rates=(1, 1, 1, 1)):
        # tf.nn.erosion2d(input, filter, strides, rates, padding, name=None)
        x = tf.compat.v1.nn.erosion2d(
            x, st_element, (1,) + strides + (1,), rates, padding.upper()
        )
        return x


class Dilation2D(Layer):
    """
    Dilation 2D Layer
    for now assuming channel last
    """

    def __init__(
        self,
        num_filters,
        kernel_size,
        strides=(1, 1),
        padding="valid",
        kernel_initializer="glorot_uniform",
        kernel_constraint=None,
        **kwargs
    ):
        super(Dilation2D, self).__init__(**kwargs)
        self.num_filters = num_filters
        self.kernel_size = kernel_size
        self.strides = strides
        self.padding = padding

        self.kernel_initializer = initializers.get(kernel_initializer)
        self.kernel_constraint = constraints.get(kernel_constraint)

        # for we are assuming channel last
        self.channel_axis = -1

        # self.output_dim = output_dim

    def build(self, input_shape):
        if input_shape[self.channel_axis] is None:
            raise ValueError(
                "The channel dimension of the inputs "
                "should be defined. Found `None`."
            )

        input_dim = input_shape[self.channel_axis]
        kernel_shape = self.kernel_size + (input_dim, self.num_filters)

        self.kernel = self.add_weight(
            shape=kernel_shape,
            initializer=self.kernel_initializer,
            name="kernel",
            constraint=self.kernel_constraint,
        )

        # Be sure to call this at the end
        super(Dilation2D, self).build(input_shape)

    def call(self, x):
        # outputs = K.placeholder()
        for i in range(self.num_filters):
            # dilation2d returns image of same size as x
            # so taking max over channel_axis
            out = K.max(
                self.__dilation2d(x, self.kernel[..., i], self.strides, self.padding),
                axis=self.channel_axis,
                keepdims=True,
            )

            if i == 0:
                outputs = out
            else:
                outputs = K.concatenate([outputs, out])

        return outputs

    def compute_output_shape(self, input_shape):
        # if self.data_format == 'channels_last':
        space = input_shape[1:-1]
        new_space = []
        for i in range(len(space)):
            new_dim = conv_utils.conv_output_length(
                space[i],
                self.kernel_size[i],
                padding=self.padding,
                stride=self.strides[i],
                dilation=1,
            )  # self.dilation_rate[i])
            new_space.append(new_dim)

        return (input_shape[0],) + tuple(new_space) + (self.num_filters,)

    def __dilation2d(self, x, st_element, strides, padding, rates=(1, 1, 1, 1)):
        # tf.nn.dilation2d(input, filter, strides, rates, padding, name=None)
        x = tf.compat.v1.nn.dilation2d(
            x, st_element, (1,) + strides + (1,), rates, padding.upper()
        )
        return x

# %%
from tensorflow import keras
import keras
from keras.models import Model
from keras.layers import Input, Lambda, BatchNormalization, Conv2D, Activation
from keras.layers import add, dot, concatenate, Concatenate, AveragePooling2D, Conv2DTranspose


def _morph_unit(inputs, filters=4, kernel=(3, 3)):
    erosion = Erosion2D(
        filters, kernel, padding="same", strides=(1, 1), kernel_initializer="he_normal"
    )(inputs)
    dilation = Dilation2D(
        filters, kernel, padding="same", strides=(1, 1), kernel_initializer="he_normal"
    )(inputs)
    xc = Concatenate()([erosion, dilation])
    xc = Conv2D(
        2 * filters,
        kernel,
        padding="same",
        activation="linear",
        kernel_initializer="he_normal",
    )(xc)
    return xc


def _bn_relu_conv_block(inputs, filters, kernel=(3, 3), stride=(1, 1)):
    x = Conv2D(
        filters,
        kernel,
        padding="same",
        use_bias=False,
        kernel_initializer="he_normal",
        strides=stride,
    )(inputs)
    x = BatchNormalization(axis=-1)(x)
    x = Activation("relu")(x)
    return x


def _grouped_morph_block(input, grouped_channels, cardinality):
    group_morph_list = []
    for c in range(cardinality):
        x = Lambda(
            lambda z: z[:, :, :, c * grouped_channels : (c + 1) * grouped_channels]
        )(input)
        x = _morph_unit(x, grouped_channels)
        group_morph_list.append(x)
    merged_output = concatenate(group_morph_list, axis=-1)
    merged_output = BatchNormalization(axis=-1)(merged_output)
    return merged_output


def _dual_path_block(
    input,
    pointwise_filters_a,
    grouped_conv_filters_b,
    pointwise_filters_c,
    filter_increment,
    cardinality,
    block_type="normal",
):
    grouped_channels = int(grouped_conv_filters_b / cardinality)
    inputs = concatenate(input, axis=-1) if isinstance(input, list) else input
    stride = (1, 1)

    if block_type == "projection":
        projection = True
    elif block_type == "normal":
        projection = False
    else:
        raise ValueError('"block_type" must be either "projection" or "normal"')

    if projection:
        projection_path = _bn_relu_conv_block(
            inputs,
            filters=pointwise_filters_c + 2 * filter_increment,
            kernel=(1, 1),
            stride=stride,
        )
        input_residual_path = Lambda(lambda z: z[:, :, :, :pointwise_filters_c])(
            projection_path
        )
        input_dense_path = Lambda(lambda z: z[:, :, :, pointwise_filters_c:])(
            projection_path
        )
    else:
        input_residual_path = input[0]
        input_dense_path = input[1]

    x = _bn_relu_conv_block(inputs, filters=pointwise_filters_a, kernel=(1, 1))
    x = _grouped_morph_block(
        x, grouped_channels=grouped_channels, cardinality=cardinality
    )
    x = _bn_relu_conv_block(
        x, filters=pointwise_filters_c + filter_increment, kernel=(1, 1)
    )

    output_residual_path = Lambda(lambda z: z[:, :, :, :pointwise_filters_c])(x)
    output_dense_path = Lambda(lambda z: z[:, :, :, pointwise_filters_c:])(x)

    residual_path = add([input_residual_path, output_residual_path])
    dense_path = concatenate([input_dense_path, output_dense_path], axis=-1)
    return [residual_path, dense_path]


def _decoder_block(inputs, skip_connection, filters):
    upsampled_input = Conv2DTranspose(
        filters=int(inputs.shape[-1]), kernel_size=(3, 3), strides=(2, 2), padding="same"
    )(inputs)
    concatenated_output = Concatenate()([upsampled_input, skip_connection])
    concatenated_output = _morph_block(concatenated_output, filters)
    return concatenated_output


def _morph_block(inputs, num_filters, filter_increment=12, cardinality=6):
    x = inputs
    x = _dual_path_block(
        x,
        num_filters,
        num_filters,
        num_filters,
        filter_increment,
        cardinality,
        "projection",
    )
    x = _dual_path_block(
        x,
        num_filters,
        num_filters,
        num_filters,
        filter_increment,
        cardinality,
        "normal",
    )
    x = concatenate(x, axis=-1)
    return x


def DPM_UNet(input_shape=(256, 256, 3)):
    inputs = Input(shape=input_shape)
    morph_ip = _morph_unit(inputs, 6)

    E1 = _morph_block(morph_ip, 12)
    pool1 = AveragePooling2D(pool_size=(2, 2))(E1)

    E2 = _morph_block(pool1, 12 * 2)
    pool2 = AveragePooling2D(pool_size=(2, 2))(E2)

    E3 = _morph_block(pool2, 12 * 3)
    pool3 = AveragePooling2D(pool_size=(2, 2))(E3)

    C = _morph_block(pool3, 12 * 4)

    D3 = _decoder_block(C, E3, 12 * 3)
    D2 = _decoder_block(D3, E2, 12 * 2)
    D1 = _decoder_block(D2, E1, 12)

    outputs = Conv2D(1, (1, 1), padding="same", activation="sigmoid")(D1)
    return Model(inputs, outputs)

# %%
model=DPM_UNet((512,512,3))
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method Erosion2D.call of <__main__.Erosion2D object at 0x000001930D2DFF10>> and will run it as-is.
# Cause: mangled names are not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Erosion2D.call of <__main__.Erosion2D object at 0x000001930D2DFF10>> and will run it as-is.
# Cause: mangled names are not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <bound method Dilation2D.call of <__main__.Dilation2D object at 0x000001930D2C7BE0>> and will run it as-is.
# Cause: mangled names are not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Dilation2D.call of <__main__.Dilation2D object at 0x000001930D2C7BE0>> and will run it as-is.
# Cause: mangled names are not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  erosion2d (Erosion2D)          (None, 512, 512, 6)  162         ['input_1[0][0]']
#
#  dilation2d (Dilation2D)        (None, 512, 512, 6)  162         ['input_1[0][0]']
#
#  concatenate (Concatenate)      (None, 512, 512, 12  0           ['erosion2d[0][0]',
#                                 )                                 'dilation2d[0][0]']
#
#  conv2d (Conv2D)                (None, 512, 512, 12  1308        ['concatenate[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 512, 512, 12  144         ['conv2d[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 12  48         ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 512, 512, 12  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  lambda_2 (Lambda)              (None, 512, 512, 2)  0           ['activation_1[0][0]']
#
#  lambda_3 (Lambda)              (None, 512, 512, 2)  0           ['activation_1[0][0]']
#
#  lambda_4 (Lambda)              (None, 512, 512, 2)  0           ['activation_1[0][0]']
#
#  lambda_5 (Lambda)              (None, 512, 512, 2)  0           ['activation_1[0][0]']
#
#  lambda_6 (Lambda)              (None, 512, 512, 2)  0           ['activation_1[0][0]']
#
#  lambda_7 (Lambda)              (None, 512, 512, 2)  0           ['activation_1[0][0]']
#
#  erosion2d_1 (Erosion2D)        (None, 512, 512, 2)  36          ['lambda_2[0][0]']
#
#  dilation2d_1 (Dilation2D)      (None, 512, 512, 2)  36          ['lambda_2[0][0]']
#
#  erosion2d_2 (Erosion2D)        (None, 512, 512, 2)  36          ['lambda_3[0][0]']
#
#  dilation2d_2 (Dilation2D)      (None, 512, 512, 2)  36          ['lambda_3[0][0]']
#
#  erosion2d_3 (Erosion2D)        (None, 512, 512, 2)  36          ['lambda_4[0][0]']
#
#  dilation2d_3 (Dilation2D)      (None, 512, 512, 2)  36          ['lambda_4[0][0]']
#
#  erosion2d_4 (Erosion2D)        (None, 512, 512, 2)  36          ['lambda_5[0][0]']
#
#  dilation2d_4 (Dilation2D)      (None, 512, 512, 2)  36          ['lambda_5[0][0]']
#
#  erosion2d_5 (Erosion2D)        (None, 512, 512, 2)  36          ['lambda_6[0][0]']
#
#  dilation2d_5 (Dilation2D)      (None, 512, 512, 2)  36          ['lambda_6[0][0]']
#
#  erosion2d_6 (Erosion2D)        (None, 512, 512, 2)  36          ['lambda_7[0][0]']
#
#  dilation2d_6 (Dilation2D)      (None, 512, 512, 2)  36          ['lambda_7[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 512, 512, 4)  0           ['erosion2d_1[0][0]',
#                                                                   'dilation2d_1[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 512, 512, 4)  0           ['erosion2d_2[0][0]',
#                                                                   'dilation2d_2[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 4)  0           ['erosion2d_3[0][0]',
#                                                                   'dilation2d_3[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 512, 512, 4)  0           ['erosion2d_4[0][0]',
#                                                                   'dilation2d_4[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 512, 512, 4)  0           ['erosion2d_5[0][0]',
#                                                                   'dilation2d_5[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 512, 512, 4)  0           ['erosion2d_6[0][0]',
#                                                                   'dilation2d_6[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 512, 512, 4)  148         ['concatenate_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 512, 512, 4)  148         ['concatenate_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 512, 512, 4)  148         ['concatenate_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 512, 512, 4)  148         ['concatenate_4[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 512, 512, 4)  148         ['concatenate_5[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 512, 512, 4)  148         ['concatenate_6[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 512, 512, 24  0           ['conv2d_3[0][0]',
#                                 )                                 'conv2d_4[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]',
#                                                                   'conv2d_7[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 512, 512, 24  96         ['concatenate_7[0][0]']
#  rmalization)                   )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 36  432         ['conv2d[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 512, 512, 24  576         ['batch_normalization_2[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 36  144        ['conv2d_1[0][0]']
#  alization)                     )
#
#  batch_normalization_3 (BatchNo  (None, 512, 512, 24  96         ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation (Activation)        (None, 512, 512, 36  0           ['batch_normalization[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 512, 512, 24  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  lambda (Lambda)                (None, 512, 512, 12  0           ['activation[0][0]']
#                                 )
#
#  lambda_8 (Lambda)              (None, 512, 512, 12  0           ['activation_2[0][0]']
#                                 )
#
#  lambda_1 (Lambda)              (None, 512, 512, 24  0           ['activation[0][0]']
#                                 )
#
#  lambda_9 (Lambda)              (None, 512, 512, 12  0           ['activation_2[0][0]']
#                                 )
#
#  add (Add)                      (None, 512, 512, 12  0           ['lambda[0][0]',
#                                 )                                 'lambda_8[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 512, 512, 36  0           ['lambda_1[0][0]',
#                                 )                                 'lambda_9[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 512, 512, 48  0           ['add[0][0]',
#                                 )                                 'concatenate_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 512, 512, 12  576         ['concatenate_9[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 512, 512, 12  48         ['conv2d_10[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 512, 512, 12  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  lambda_10 (Lambda)             (None, 512, 512, 2)  0           ['activation_3[0][0]']
#
#  lambda_11 (Lambda)             (None, 512, 512, 2)  0           ['activation_3[0][0]']
#
#  lambda_12 (Lambda)             (None, 512, 512, 2)  0           ['activation_3[0][0]']
#
#  lambda_13 (Lambda)             (None, 512, 512, 2)  0           ['activation_3[0][0]']
#
#  lambda_14 (Lambda)             (None, 512, 512, 2)  0           ['activation_3[0][0]']
#
#  lambda_15 (Lambda)             (None, 512, 512, 2)  0           ['activation_3[0][0]']
#
#  erosion2d_7 (Erosion2D)        (None, 512, 512, 2)  36          ['lambda_10[0][0]']
#
#  dilation2d_7 (Dilation2D)      (None, 512, 512, 2)  36          ['lambda_10[0][0]']
#
#  erosion2d_8 (Erosion2D)        (None, 512, 512, 2)  36          ['lambda_11[0][0]']
#
#  dilation2d_8 (Dilation2D)      (None, 512, 512, 2)  36          ['lambda_11[0][0]']
#
#  erosion2d_9 (Erosion2D)        (None, 512, 512, 2)  36          ['lambda_12[0][0]']
#
#  dilation2d_9 (Dilation2D)      (None, 512, 512, 2)  36          ['lambda_12[0][0]']
#
#  erosion2d_10 (Erosion2D)       (None, 512, 512, 2)  36          ['lambda_13[0][0]']
#
#  dilation2d_10 (Dilation2D)     (None, 512, 512, 2)  36          ['lambda_13[0][0]']
#
#  erosion2d_11 (Erosion2D)       (None, 512, 512, 2)  36          ['lambda_14[0][0]']
#
#  dilation2d_11 (Dilation2D)     (None, 512, 512, 2)  36          ['lambda_14[0][0]']
#
#  erosion2d_12 (Erosion2D)       (None, 512, 512, 2)  36          ['lambda_15[0][0]']
#
#  dilation2d_12 (Dilation2D)     (None, 512, 512, 2)  36          ['lambda_15[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 512, 512, 4)  0           ['erosion2d_7[0][0]',
#                                                                   'dilation2d_7[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 512, 512, 4)  0           ['erosion2d_8[0][0]',
#                                                                   'dilation2d_8[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 512, 512, 4)  0           ['erosion2d_9[0][0]',
#                                                                   'dilation2d_9[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 512, 512, 4)  0           ['erosion2d_10[0][0]',
#                                                                   'dilation2d_10[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 512, 512, 4)  0           ['erosion2d_11[0][0]',
#                                                                   'dilation2d_11[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 512, 512, 4)  0           ['erosion2d_12[0][0]',
#                                                                   'dilation2d_12[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 512, 512, 4)  148         ['concatenate_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 512, 512, 4)  148         ['concatenate_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 512, 512, 4)  148         ['concatenate_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 512, 512, 4)  148         ['concatenate_13[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 512, 512, 4)  148         ['concatenate_14[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 512, 512, 4)  148         ['concatenate_15[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 512, 512, 24  0           ['conv2d_11[0][0]',
#                                 )                                 'conv2d_12[0][0]',
#                                                                   'conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]',
#                                                                   'conv2d_15[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 512, 512, 24  96         ['concatenate_16[0][0]']
#  rmalization)                   )
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 24  576         ['batch_normalization_5[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 512, 512, 24  96         ['conv2d_17[0][0]']
#  rmalization)                   )
#
#  activation_4 (Activation)      (None, 512, 512, 24  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  lambda_16 (Lambda)             (None, 512, 512, 12  0           ['activation_4[0][0]']
#                                 )
#
#  lambda_17 (Lambda)             (None, 512, 512, 12  0           ['activation_4[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 512, 512, 12  0           ['add[0][0]',
#                                 )                                 'lambda_16[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 512, 512, 48  0           ['concatenate_8[0][0]',
#                                 )                                 'lambda_17[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 512, 512, 60  0           ['add_1[0][0]',
#                                 )                                 'concatenate_17[0][0]']
#
#  average_pooling2d (AveragePool  (None, 256, 256, 60  0          ['concatenate_18[0][0]']
#  ing2D)                         )
#
#  conv2d_19 (Conv2D)             (None, 256, 256, 24  1440        ['average_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 256, 256, 24  96         ['conv2d_19[0][0]']
#  rmalization)                   )
#
#  activation_6 (Activation)      (None, 256, 256, 24  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  lambda_20 (Lambda)             (None, 256, 256, 4)  0           ['activation_6[0][0]']
#
#  lambda_21 (Lambda)             (None, 256, 256, 4)  0           ['activation_6[0][0]']
#
#  lambda_22 (Lambda)             (None, 256, 256, 4)  0           ['activation_6[0][0]']
#
#  lambda_23 (Lambda)             (None, 256, 256, 4)  0           ['activation_6[0][0]']
#
#  lambda_24 (Lambda)             (None, 256, 256, 4)  0           ['activation_6[0][0]']
#
#  lambda_25 (Lambda)             (None, 256, 256, 4)  0           ['activation_6[0][0]']
#
#  erosion2d_13 (Erosion2D)       (None, 256, 256, 4)  144         ['lambda_20[0][0]']
#
#  dilation2d_13 (Dilation2D)     (None, 256, 256, 4)  144         ['lambda_20[0][0]']
#
#  erosion2d_14 (Erosion2D)       (None, 256, 256, 4)  144         ['lambda_21[0][0]']
#
#  dilation2d_14 (Dilation2D)     (None, 256, 256, 4)  144         ['lambda_21[0][0]']
#
#  erosion2d_15 (Erosion2D)       (None, 256, 256, 4)  144         ['lambda_22[0][0]']
#
#  dilation2d_15 (Dilation2D)     (None, 256, 256, 4)  144         ['lambda_22[0][0]']
#
#  erosion2d_16 (Erosion2D)       (None, 256, 256, 4)  144         ['lambda_23[0][0]']
#
#  dilation2d_16 (Dilation2D)     (None, 256, 256, 4)  144         ['lambda_23[0][0]']
#
#  erosion2d_17 (Erosion2D)       (None, 256, 256, 4)  144         ['lambda_24[0][0]']
#
#  dilation2d_17 (Dilation2D)     (None, 256, 256, 4)  144         ['lambda_24[0][0]']
#
#  erosion2d_18 (Erosion2D)       (None, 256, 256, 4)  144         ['lambda_25[0][0]']
#
#  dilation2d_18 (Dilation2D)     (None, 256, 256, 4)  144         ['lambda_25[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 256, 256, 8)  0           ['erosion2d_13[0][0]',
#                                                                   'dilation2d_13[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 256, 256, 8)  0           ['erosion2d_14[0][0]',
#                                                                   'dilation2d_14[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 256, 256, 8)  0           ['erosion2d_15[0][0]',
#                                                                   'dilation2d_15[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 256, 256, 8)  0           ['erosion2d_16[0][0]',
#                                                                   'dilation2d_16[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 256, 256, 8)  0           ['erosion2d_17[0][0]',
#                                                                   'dilation2d_17[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 256, 256, 8)  0           ['erosion2d_18[0][0]',
#                                                                   'dilation2d_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 256, 256, 8)  584         ['concatenate_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 256, 256, 8)  584         ['concatenate_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 256, 256, 8)  584         ['concatenate_21[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 256, 256, 8)  584         ['concatenate_22[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 256, 256, 8)  584         ['concatenate_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 256, 256, 8)  584         ['concatenate_24[0][0]']
#
#  concatenate_25 (Concatenate)   (None, 256, 256, 48  0           ['conv2d_20[0][0]',
#                                 )                                 'conv2d_21[0][0]',
#                                                                   'conv2d_22[0][0]',
#                                                                   'conv2d_23[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 256, 256, 48  192        ['concatenate_25[0][0]']
#  rmalization)                   )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 48  2880        ['average_pooling2d[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 256, 256, 36  1728        ['batch_normalization_9[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 256, 256, 48  192        ['conv2d_18[0][0]']
#  rmalization)                   )
#
#  batch_normalization_10 (BatchN  (None, 256, 256, 36  144        ['conv2d_26[0][0]']
#  ormalization)                  )
#
#  activation_5 (Activation)      (None, 256, 256, 48  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  activation_7 (Activation)      (None, 256, 256, 36  0           ['batch_normalization_10[0][0]']
#                                 )
#
#  lambda_18 (Lambda)             (None, 256, 256, 24  0           ['activation_5[0][0]']
#                                 )
#
#  lambda_26 (Lambda)             (None, 256, 256, 24  0           ['activation_7[0][0]']
#                                 )
#
#  lambda_19 (Lambda)             (None, 256, 256, 24  0           ['activation_5[0][0]']
#                                 )
#
#  lambda_27 (Lambda)             (None, 256, 256, 12  0           ['activation_7[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 256, 256, 24  0           ['lambda_18[0][0]',
#                                 )                                 'lambda_26[0][0]']
#
#  concatenate_26 (Concatenate)   (None, 256, 256, 36  0           ['lambda_19[0][0]',
#                                 )                                 'lambda_27[0][0]']
#
#  concatenate_27 (Concatenate)   (None, 256, 256, 60  0           ['add_2[0][0]',
#                                 )                                 'concatenate_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 256, 256, 24  1440        ['concatenate_27[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 256, 256, 24  96         ['conv2d_27[0][0]']
#  ormalization)                  )
#
#  activation_8 (Activation)      (None, 256, 256, 24  0           ['batch_normalization_11[0][0]']
#                                 )
#
#  lambda_28 (Lambda)             (None, 256, 256, 4)  0           ['activation_8[0][0]']
#
#  lambda_29 (Lambda)             (None, 256, 256, 4)  0           ['activation_8[0][0]']
#
#  lambda_30 (Lambda)             (None, 256, 256, 4)  0           ['activation_8[0][0]']
#
#  lambda_31 (Lambda)             (None, 256, 256, 4)  0           ['activation_8[0][0]']
#
#  lambda_32 (Lambda)             (None, 256, 256, 4)  0           ['activation_8[0][0]']
#
#  lambda_33 (Lambda)             (None, 256, 256, 4)  0           ['activation_8[0][0]']
#
#  erosion2d_19 (Erosion2D)       (None, 256, 256, 4)  144         ['lambda_28[0][0]']
#
#  dilation2d_19 (Dilation2D)     (None, 256, 256, 4)  144         ['lambda_28[0][0]']
#
#  erosion2d_20 (Erosion2D)       (None, 256, 256, 4)  144         ['lambda_29[0][0]']
#
#  dilation2d_20 (Dilation2D)     (None, 256, 256, 4)  144         ['lambda_29[0][0]']
#
#  erosion2d_21 (Erosion2D)       (None, 256, 256, 4)  144         ['lambda_30[0][0]']
#
#  dilation2d_21 (Dilation2D)     (None, 256, 256, 4)  144         ['lambda_30[0][0]']
#
#  erosion2d_22 (Erosion2D)       (None, 256, 256, 4)  144         ['lambda_31[0][0]']
#
#  dilation2d_22 (Dilation2D)     (None, 256, 256, 4)  144         ['lambda_31[0][0]']
#
#  erosion2d_23 (Erosion2D)       (None, 256, 256, 4)  144         ['lambda_32[0][0]']
#
#  dilation2d_23 (Dilation2D)     (None, 256, 256, 4)  144         ['lambda_32[0][0]']
#
#  erosion2d_24 (Erosion2D)       (None, 256, 256, 4)  144         ['lambda_33[0][0]']
#
#  dilation2d_24 (Dilation2D)     (None, 256, 256, 4)  144         ['lambda_33[0][0]']
#
#  concatenate_28 (Concatenate)   (None, 256, 256, 8)  0           ['erosion2d_19[0][0]',
#                                                                   'dilation2d_19[0][0]']
#
#  concatenate_29 (Concatenate)   (None, 256, 256, 8)  0           ['erosion2d_20[0][0]',
#                                                                   'dilation2d_20[0][0]']
#
#  concatenate_30 (Concatenate)   (None, 256, 256, 8)  0           ['erosion2d_21[0][0]',
#                                                                   'dilation2d_21[0][0]']
#
#  concatenate_31 (Concatenate)   (None, 256, 256, 8)  0           ['erosion2d_22[0][0]',
#                                                                   'dilation2d_22[0][0]']
#
#  concatenate_32 (Concatenate)   (None, 256, 256, 8)  0           ['erosion2d_23[0][0]',
#                                                                   'dilation2d_23[0][0]']
#
#  concatenate_33 (Concatenate)   (None, 256, 256, 8)  0           ['erosion2d_24[0][0]',
#                                                                   'dilation2d_24[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 256, 256, 8)  584         ['concatenate_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 256, 256, 8)  584         ['concatenate_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 256, 256, 8)  584         ['concatenate_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 256, 256, 8)  584         ['concatenate_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 256, 256, 8)  584         ['concatenate_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 256, 256, 8)  584         ['concatenate_33[0][0]']
#
#  concatenate_34 (Concatenate)   (None, 256, 256, 48  0           ['conv2d_28[0][0]',
#                                 )                                 'conv2d_29[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'conv2d_31[0][0]',
#                                                                   'conv2d_32[0][0]',
#                                                                   'conv2d_33[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 256, 256, 48  192        ['concatenate_34[0][0]']
#  ormalization)                  )
#
#  conv2d_34 (Conv2D)             (None, 256, 256, 36  1728        ['batch_normalization_12[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 256, 256, 36  144        ['conv2d_34[0][0]']
#  ormalization)                  )
#
#  activation_9 (Activation)      (None, 256, 256, 36  0           ['batch_normalization_13[0][0]']
#                                 )
#
#  lambda_34 (Lambda)             (None, 256, 256, 24  0           ['activation_9[0][0]']
#                                 )
#
#  lambda_35 (Lambda)             (None, 256, 256, 12  0           ['activation_9[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 256, 256, 24  0           ['add_2[0][0]',
#                                 )                                 'lambda_34[0][0]']
#
#  concatenate_35 (Concatenate)   (None, 256, 256, 48  0           ['concatenate_26[0][0]',
#                                 )                                 'lambda_35[0][0]']
#
#  concatenate_36 (Concatenate)   (None, 256, 256, 72  0           ['add_3[0][0]',
#                                 )                                 'concatenate_35[0][0]']
# ...
#                                                                   'conv2d_107[0][0]',
#                                                                   'conv2d_108[0][0]',
#                                                                   'conv2d_109[0][0]',
#                                                                   'conv2d_110[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 512, 512, 24  96         ['concatenate_118[0][0]']
#  ormalization)                  )
#
#  conv2d_103 (Conv2D)            (None, 512, 512, 36  4752        ['concatenate_111[0][0]']
#                                 )
#
#  conv2d_111 (Conv2D)            (None, 512, 512, 24  576         ['batch_normalization_44[0][0]']
#                                 )
#
#  batch_normalization_42 (BatchN  (None, 512, 512, 36  144        ['conv2d_103[0][0]']
#  ormalization)                  )
#
#  batch_normalization_45 (BatchN  (None, 512, 512, 24  96         ['conv2d_111[0][0]']
#  ormalization)                  )
#
#  activation_30 (Activation)     (None, 512, 512, 36  0           ['batch_normalization_42[0][0]']
#                                 )
#
#  activation_32 (Activation)     (None, 512, 512, 24  0           ['batch_normalization_45[0][0]']
#                                 )
#
#  lambda_108 (Lambda)            (None, 512, 512, 12  0           ['activation_30[0][0]']
#                                 )
#
#  lambda_116 (Lambda)            (None, 512, 512, 12  0           ['activation_32[0][0]']
#                                 )
#
#  lambda_109 (Lambda)            (None, 512, 512, 24  0           ['activation_30[0][0]']
#                                 )
#
#  lambda_117 (Lambda)            (None, 512, 512, 12  0           ['activation_32[0][0]']
#                                 )
#
#  add_12 (Add)                   (None, 512, 512, 12  0           ['lambda_108[0][0]',
#                                 )                                 'lambda_116[0][0]']
#
#  concatenate_119 (Concatenate)  (None, 512, 512, 36  0           ['lambda_109[0][0]',
#                                 )                                 'lambda_117[0][0]']
#
#  concatenate_120 (Concatenate)  (None, 512, 512, 48  0           ['add_12[0][0]',
#                                 )                                 'concatenate_119[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 512, 512, 12  576         ['concatenate_120[0][0]']
#                                 )
#
#  batch_normalization_46 (BatchN  (None, 512, 512, 12  48         ['conv2d_112[0][0]']
#  ormalization)                  )
#
#  activation_33 (Activation)     (None, 512, 512, 12  0           ['batch_normalization_46[0][0]']
#                                 )
#
#  lambda_118 (Lambda)            (None, 512, 512, 2)  0           ['activation_33[0][0]']
#
#  lambda_119 (Lambda)            (None, 512, 512, 2)  0           ['activation_33[0][0]']
#
#  lambda_120 (Lambda)            (None, 512, 512, 2)  0           ['activation_33[0][0]']
#
#  lambda_121 (Lambda)            (None, 512, 512, 2)  0           ['activation_33[0][0]']
#
#  lambda_122 (Lambda)            (None, 512, 512, 2)  0           ['activation_33[0][0]']
#
#  lambda_123 (Lambda)            (None, 512, 512, 2)  0           ['activation_33[0][0]']
#
#  erosion2d_79 (Erosion2D)       (None, 512, 512, 2)  36          ['lambda_118[0][0]']
#
#  dilation2d_79 (Dilation2D)     (None, 512, 512, 2)  36          ['lambda_118[0][0]']
#
#  erosion2d_80 (Erosion2D)       (None, 512, 512, 2)  36          ['lambda_119[0][0]']
#
#  dilation2d_80 (Dilation2D)     (None, 512, 512, 2)  36          ['lambda_119[0][0]']
#
#  erosion2d_81 (Erosion2D)       (None, 512, 512, 2)  36          ['lambda_120[0][0]']
#
#  dilation2d_81 (Dilation2D)     (None, 512, 512, 2)  36          ['lambda_120[0][0]']
#
#  erosion2d_82 (Erosion2D)       (None, 512, 512, 2)  36          ['lambda_121[0][0]']
#
#  dilation2d_82 (Dilation2D)     (None, 512, 512, 2)  36          ['lambda_121[0][0]']
#
#  erosion2d_83 (Erosion2D)       (None, 512, 512, 2)  36          ['lambda_122[0][0]']
#
#  dilation2d_83 (Dilation2D)     (None, 512, 512, 2)  36          ['lambda_122[0][0]']
#
#  erosion2d_84 (Erosion2D)       (None, 512, 512, 2)  36          ['lambda_123[0][0]']
#
#  dilation2d_84 (Dilation2D)     (None, 512, 512, 2)  36          ['lambda_123[0][0]']
#
#  concatenate_121 (Concatenate)  (None, 512, 512, 4)  0           ['erosion2d_79[0][0]',
#                                                                   'dilation2d_79[0][0]']
#
#  concatenate_122 (Concatenate)  (None, 512, 512, 4)  0           ['erosion2d_80[0][0]',
#                                                                   'dilation2d_80[0][0]']
#
#  concatenate_123 (Concatenate)  (None, 512, 512, 4)  0           ['erosion2d_81[0][0]',
#                                                                   'dilation2d_81[0][0]']
#
#  concatenate_124 (Concatenate)  (None, 512, 512, 4)  0           ['erosion2d_82[0][0]',
#                                                                   'dilation2d_82[0][0]']
#
#  concatenate_125 (Concatenate)  (None, 512, 512, 4)  0           ['erosion2d_83[0][0]',
#                                                                   'dilation2d_83[0][0]']
#
#  concatenate_126 (Concatenate)  (None, 512, 512, 4)  0           ['erosion2d_84[0][0]',
#                                                                   'dilation2d_84[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 512, 512, 4)  148         ['concatenate_121[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 512, 512, 4)  148         ['concatenate_122[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 512, 512, 4)  148         ['concatenate_123[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 512, 512, 4)  148         ['concatenate_124[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 512, 512, 4)  148         ['concatenate_125[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 512, 512, 4)  148         ['concatenate_126[0][0]']
#
#  concatenate_127 (Concatenate)  (None, 512, 512, 24  0           ['conv2d_113[0][0]',
#                                 )                                 'conv2d_114[0][0]',
#                                                                   'conv2d_115[0][0]',
#                                                                   'conv2d_116[0][0]',
#                                                                   'conv2d_117[0][0]',
#                                                                   'conv2d_118[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 512, 512, 24  96         ['concatenate_127[0][0]']
#  ormalization)                  )
#
#  conv2d_119 (Conv2D)            (None, 512, 512, 24  576         ['batch_normalization_47[0][0]']
#                                 )
#
#  batch_normalization_48 (BatchN  (None, 512, 512, 24  96         ['conv2d_119[0][0]']
#  ormalization)                  )
#
#  activation_34 (Activation)     (None, 512, 512, 24  0           ['batch_normalization_48[0][0]']
#                                 )
#
#  lambda_124 (Lambda)            (None, 512, 512, 12  0           ['activation_34[0][0]']
#                                 )
#
#  lambda_125 (Lambda)            (None, 512, 512, 12  0           ['activation_34[0][0]']
#                                 )
#
#  add_13 (Add)                   (None, 512, 512, 12  0           ['add_12[0][0]',
#                                 )                                 'lambda_124[0][0]']
#
#  concatenate_128 (Concatenate)  (None, 512, 512, 48  0           ['concatenate_119[0][0]',
#                                 )                                 'lambda_125[0][0]']
#
#  concatenate_129 (Concatenate)  (None, 512, 512, 60  0           ['add_13[0][0]',
#                                 )                                 'concatenate_128[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 512, 512, 1)  61          ['concatenate_129[0][0]']
#
# ==================================================================================================
# Total params: 422,665
# Trainable params: 418,537
# Non-trainable params: 4,128
# __________________________________________________________________________________________________

# %%
def dice(y_true, y_pred):
    smooth = 1.0
    y_true = K.cast(y_true, dtype='float32')  # Cast to float32
    y_pred = K.cast(y_pred, dtype='float32')  # Cast to float32
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice_score = (2.0 * intersection + smooth) / (
        K.sum(y_true_f) + K.sum(y_pred_f) + smooth
    )
    return dice_score

def dice_loss(y_true, y_pred):
    loss = 1 - dice(y_true, y_pred)
    return loss

# %%
opt = Adam(learning_rate=3e-4)
model.compile(optimizer=opt, loss=dice_loss, metrics=['accuracy', iou_coef,dice, precision, recall])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 opt = Adam(learning_rate=3e-4)
#       2 model.compile(optimizer=opt, loss=dice_loss, metrics=['accuracy', iou_coef,dice, precision, recall])
#
# NameError: name 'Adam' is not defined

# %%
callbacks = create_callbacks()
history = model.fit(train_gen, validation_data=val_gen, batch_size=1,shuffle=True, verbose=1
                                  ,epochs = 50, callbacks = callbacks )
# Out:
# Epoch 1/50
# 1233/1233 [==============================] - ETA: 0s - loss: 0.5782 - accuracy: 0.8419 - iou_coef: 0.2878 - dice: 0.4218 - precision: 0.3905 - recall: 0.6297
# Epoch 00001: val_loss improved from inf to 0.50531, saving model to .\morphUnet_building.h5
# 1233/1233 [==============================] - 6564s 5s/step - loss: 0.5782 - accuracy: 0.8419 - iou_coef: 0.2878 - dice: 0.4218 - precision: 0.3905 - recall: 0.6297 - val_loss: 0.5053 - val_accuracy: 0.8497 - val_iou_coef: 0.3349 - val_dice: 0.4947 - val_precision: 0.3713 - val_recall: 0.7825 - lr: 3.0000e-04
# Epoch 2/50
# 1233/1233 [==============================] - ETA: 0s - loss: 0.4961 - accuracy: 0.8863 - iou_coef: 0.3619 - dice: 0.5039 - precision: 0.4987 - recall: 0.6265
# Epoch 00002: val_loss improved from 0.50531 to 0.49151, saving model to .\morphUnet_building.h5
# 1233/1233 [==============================] - 7078s 6s/step - loss: 0.4961 - accuracy: 0.8863 - iou_coef: 0.3619 - dice: 0.5039 - precision: 0.4987 - recall: 0.6265 - val_loss: 0.4915 - val_accuracy: 0.9212 - val_iou_coef: 0.3535 - val_dice: 0.5085 - val_precision: 0.7038 - val_recall: 0.4183 - lr: 3.0000e-04
# Epoch 3/50
# 1233/1233 [==============================] - ETA: 0s - loss: 0.4621 - accuracy: 0.8934 - iou_coef: 0.3946 - dice: 0.5379 - precision: 0.5312 - recall: 0.6419
# Epoch 00003: val_loss improved from 0.49151 to 0.40625, saving model to .\morphUnet_building.h5
# 1233/1233 [==============================] - 7079s 6s/step - loss: 0.4621 - accuracy: 0.8934 - iou_coef: 0.3946 - dice: 0.5379 - precision: 0.5312 - recall: 0.6419 - val_loss: 0.4063 - val_accuracy: 0.9035 - val_iou_coef: 0.4297 - val_dice: 0.5937 - val_precision: 0.5100 - val_recall: 0.7426 - lr: 3.0000e-04
# Epoch 4/50
# 1233/1233 [==============================] - ETA: 0s - loss: 0.4440 - accuracy: 0.8939 - iou_coef: 0.4110 - dice: 0.5560 - precision: 0.5480 - recall: 0.6536
# Epoch 00004: val_loss did not improve from 0.40625
# 1233/1233 [==============================] - 6945s 6s/step - loss: 0.4440 - accuracy: 0.8939 - iou_coef: 0.4110 - dice: 0.5560 - precision: 0.5480 - recall: 0.6536 - val_loss: 0.8855 - val_accuracy: 0.9014 - val_iou_coef: 0.0626 - val_dice: 0.1145 - val_precision: 0.7909 - val_recall: 0.0638 - lr: 3.0000e-04
# Epoch 5/50
# 1233/1233 [==============================] - ETA: 0s - loss: 0.4346 - accuracy: 0.8948 - iou_coef: 0.4211 - dice: 0.5654 - precision: 0.5573 - recall: 0.6594
# Epoch 00005: val_loss improved from 0.40625 to 0.39746, saving model to .\morphUnet_building.h5
# 1233/1233 [==============================] - 6888s 6s/step - loss: 0.4346 - accuracy: 0.8948 - iou_coef: 0.4211 - dice: 0.5654 - precision: 0.5573 - recall: 0.6594 - val_loss: 0.3975 - val_accuracy: 0.9320 - val_iou_coef: 0.4434 - val_dice: 0.6025 - val_precision: 0.7508 - val_recall: 0.5289 - lr: 3.0000e-04
# Epoch 6/50
# 1233/1233 [==============================] - ETA: 0s - loss: 0.4258 - accuracy: 0.8966 - iou_coef: 0.4297 - dice: 0.5742 - precision: 0.5666 - recall: 0.6664
# Epoch 00006: val_loss improved from 0.39746 to 0.37449, saving model to .\morphUnet_building.h5
# 1233/1233 [==============================] - 6850s 6s/step - loss: 0.4258 - accuracy: 0.8966 - iou_coef: 0.4297 - dice: 0.5742 - precision: 0.5666 - recall: 0.6664 - val_loss: 0.3745 - val_accuracy: 0.9330 - val_iou_coef: 0.4664 - val_dice: 0.6255 - val_precision: 0.7083 - val_recall: 0.5880 - lr: 3.0000e-04
# Epoch 7/50
# 1233/1233 [==============================] - ETA: 0s - loss: 0.4202 - accuracy: 0.8953 - iou_coef: 0.4355 - dice: 0.5798 - precision: 0.5701 - recall: 0.6751
# Epoch 00007: val_loss improved from 0.37449 to 0.37082, saving model to .\morphUnet_building.h5
# 1233/1233 [==============================] - 6894s 6s/step - loss: 0.4202 - accuracy: 0.8953 - iou_coef: 0.4355 - dice: 0.5798 - precision: 0.5701 - recall: 0.6751 - val_loss: 0.3708 - val_accuracy: 0.9281 - val_iou_coef: 0.4680 - val_dice: 0.6292 - val_precision: 0.6871 - val_recall: 0.6050 - lr: 3.0000e-04
# Epoch 8/50
# 1165/1233 [===========================>..] - ETA: 6:15 - loss: 0.4117 - accuracy: 0.8971 - iou_coef: 0.4444 - dice: 0.5883 - precision: 0.5787 - recall: 0.6788

# %%
# Save the history object
import numpy as np
#np.save('training_history_morph_Unet.npy', history.history)

# Load the history object
loaded_history = np.load('training_history_morph_Unet.npy', allow_pickle='TRUE').item()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 6
#       2 import numpy as np
#       3 #np.save('training_history_morph_Unet.npy', history.history)
#       4
#       5 # Load the history object
# ----> 6 loaded_history = np.load('training_history_morph_Unet.npy', allow_pickle='TRUE').item()
#
# File ~\anaconda3\envs\pavithra\lib\site-packages\numpy\lib\npyio.py:416, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     414     own_fid = False
#     415 else:
# --> 416     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     417     own_fid = True
#     419 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'training_history_morph_Unet.npy'

# %%
plot_history(loaded_history)

# %%
# y_pred = model.predict(x_test)
# y_pred = y_pred>0.5

# %%
model.load_weights('morphUnet_building.h5')

# %%
y_predicted=[]
for i in range(len(x_test)):
    image= np.expand_dims(x_test[i], axis=0)

    y_pred = dppnetmodel.predict(image)
    y_pred=y_pred>0.5
    y_predicted.append(y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 y_predicted=[]
# ----> 2 for i in range(len(x_test)):
#       3     image= np.expand_dims(x_test[i], axis=0)
#       5     y_pred = dppnetmodel.predict(image)
#
# NameError: name 'x_test' is not defined

# %%
visualize_predictions(x_test, y_test, y_predicted, num_samples=9)

# %%
from sklearn.metrics import *
gt=(y_test.ravel()).astype('int')
pd=(np.array(y_predicted).ravel()).astype('int')
f1 = f1_score(gt,pd,average='macro')
kappa = cohen_kappa_score(gt,pd)
accuracy = accuracy_score(gt,pd)
jaccard = jaccard_score(gt,pd,average='macro')
precision = precision_score(gt,pd,average='macro')
recall = recall_score(gt,pd,average='macro')
print(np.unique(gt),np.unique(pd))
print("F1 SCORE:", f1)
print("Kappa:",kappa)
print("Accuracy:",accuracy)
print("Jaccard Score:",jaccard)
print("Precision:",precision)
print("Recall:",recall)
